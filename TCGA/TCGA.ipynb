# %% [markdown]
# ## Find HCA project data on TCGA cancer tissues

# %%
import pandas as pd

a = pd.read_csv("TCGA.csv")
Disease_set = set(a["Disease"].values.tolist())
Tissues = set(a["Tissue(Primary site)"].values.tolist())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
Tissues # Primary site in TCGA
# Out:
# {'Adrenal gland',
#  'Bile duct',
#  'Bladder',
#  'Bone',
#  'Bone Marrow',
#  'Brain',
#  'Breast',
#  'Cervix',
#  'Colorectal',
#  'Esophagus',
#  'Eye',
#  'Head and Neck',
#  'Kidney',
#  'Liver',
#  'Lung',
#  'Lymph Nodes',
#  'Nervous System',
#  'Ovary',
#  'Pancreas',
#  'Pleura',
#  'Prostate',
#  'Skin',
#  'Soft Tissue',
#  'Stomach',
#  'Testis',
#  'Thymus',
#  'Thyroid',
#  'Uterus'}

# %%
import os
path = 'E:\\HCA_save\\project metadata'
os.chdir(path)

HCA_meta = pd.read_csv("HCA-project-metadata.tsv", sep = '\t') # The project metadata in HCA

# %%
HCA_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316581 entries, 0 to 316580
# Data columns (total 55 columns):
#  #   Column                                                           Non-Null Count   Dtype
# ---  ------                                                           --------------   -----
#  0   source_id                                                        316581 non-null  object
#  1   source_name                                                      316581 non-null  object
#  2   bundle_uuid                                                      316581 non-null  object
#  3   bundle_version                                                   316581 non-null  object
#  4   file_document_id                                                 316581 non-null  object
#  5   file_type                                                        316581 non-null  object
#  6   file_name                                                        316581 non-null  object
#  7   file_format                                                      316581 non-null  object
#  8   read_index                                                       312904 non-null  object
#  9   file_size                                                        316581 non-null  float64
#  10  file_uuid                                                        316581 non-null  object
#  11  file_version                                                     316581 non-null  object
#  12  file_crc32c                                                      316581 non-null  object
#  13  file_sha256                                                      316581 non-null  object
#  14  file_content_type                                                316581 non-null  object
#  15  file_drs_uri                                                     316581 non-null  object
#  16  file_url                                                         316581 non-null  object
#  17  cell_suspension.provenance.document_id                           313034 non-null  object
#  18  cell_suspension.biomaterial_core.biomaterial_id                  313034 non-null  object
#  19  cell_suspension.estimated_cell_count                             289108 non-null  float64
#  20  cell_suspension.selected_cell_type                               81576 non-null   object
#  21  sequencing_process.provenance.document_id                        314800 non-null  object
#  22  sequencing_protocol.instrument_manufacturer_model                314800 non-null  object
#  23  sequencing_protocol.paired_end                                   314800 non-null  object
#  24  library_preparation_protocol.library_construction_approach       315077 non-null  object
#  25  library_preparation_protocol.nucleic_acid_source                 314800 non-null  object
#  26  project.provenance.document_id                                   316581 non-null  object
#  27  project.contributors.institution                                 316581 non-null  object
#  28  project.contributors.laboratory                                  306216 non-null  object
#  29  project.project_core.project_short_name                          316581 non-null  object
#  30  project.project_core.project_title                               316581 non-null  object
#  31  specimen_from_organism.provenance.document_id                    314753 non-null  object
#  32  specimen_from_organism.diseases                                  79471 non-null   object
#  33  specimen_from_organism.organ                                     315031 non-null  object
#  34  specimen_from_organism.organ_part                                67481 non-null   object
#  35  specimen_from_organism.preservation_storage.preservation_method  49097 non-null   object
#  36  donor_organism.sex                                               314753 non-null  object
#  37  donor_organism.biomaterial_core.biomaterial_id                   315031 non-null  object
#  38  donor_organism.provenance.document_id                            314753 non-null  object
#  39  donor_organism.genus_species                                     315031 non-null  object
#  40  donor_organism.development_stage                                 315031 non-null  object
#  41  donor_organism.diseases                                          301005 non-null  object
#  42  donor_organism.organism_age                                      281179 non-null  object
#  43  cell_line.provenance.document_id                                 3646 non-null    object
#  44  cell_line.biomaterial_core.biomaterial_id                        3646 non-null    object
#  45  organoid.provenance.document_id                                  1080 non-null    object
#  46  organoid.biomaterial_core.biomaterial_id                         1080 non-null    object
#  47  organoid.model_organ                                             1080 non-null    object
#  48  organoid.model_organ_part                                        0 non-null       float64
#  49  _entity_type                                                     314799 non-null  object
#  50  sample.provenance.document_id                                    314799 non-null  object
#  51  sample.biomaterial_core.biomaterial_id                           314799 non-null  object
#  52  sequencing_input.provenance.document_id                          316303 non-null  object
#  53  sequencing_input.biomaterial_core.biomaterial_id                 316303 non-null  object
#  54  sequencing_input_type                                            316303 non-null  object
# dtypes: float64(3), object(52)
# memory usage: 132.8+ MB

# %%
project_organ = HCA_meta[['project.project_core.project_title', 'specimen_from_organism.organ', 'specimen_from_organism.organ_part']]
project_organ.head()
# Out:
#                   project.project_core.project_title  \
# 0  Melanoma infiltration of stromal and immune cells
# 1  Reconstructing the human first trimester fetal...
# 2  Tabula Muris: Transcriptomic characterization ...
# 3  Tabula Muris: Transcriptomic characterization ...
# 4  Tabula Muris: Transcriptomic characterization ...
#
#   specimen_from_organism.organ specimen_from_organism.organ_part
# 0                        tumor                               NaN
# 1                      decidua                               NaN
# 2                 muscle organ                               NaN
# 3                        heart                               NaN
# 4                        heart                               NaN

# %%
cleaned = project_organ.dropna(axis = 0, thresh = 2)  # remove rows with both organ and organ_part are NaN 
cleaned.values
# Out:
# array([['Melanoma infiltration of stromal and immune cells', 'tumor',
#         nan],
#        ['Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics',
#         'decidua', nan],
#        ['Tabula Muris: Transcriptomic characterization of 20 organs and tissues from Mus musculus at single cell resolution',
#         'muscle organ', nan],
#        ...,
#        ['Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis',
#         'blood', 'peripheral blood mononuclear cell'],
#        ['A single-cell molecular map of mouse gastrulation and early organogenesis',
#         'embryo', nan],
#        ['Single-Cell RNAseq analysis of diffuse neoplastic infiltrating cells at the migrating front of human glioblastoma',
#         'brain', 'cerebral cortex']], dtype=object)

# %%
organ_and_organ_part_pairs = set([tuple(xi) for xi in cleaned[['specimen_from_organism.organ', 'specimen_from_organism.organ_part']].values])
organ_and_organ_part_pairs # Find all pairs of organ and organ part, match each pair, if proper, to a TCGA cancer primary site
# Out:
# {('Immune system', 'cerebrospinal fluid'),
#  ('abdomen', 'dermis'),
#  ('adipose tissue || aorta || bladder organ || bone tissue || brain || diaphragm || heart || kidney || large intestine || liver || lung || mammary gland || muscle organ || pancreas || skin of body || spleen || thymus || tongue || trachea',
#   nan),
#  ('adipose tissue',
#   'axillary fat pad || inguinal fat pad || white adipose tissue'),
#  ('adipose tissue', 'subcutaneous abdominal adipose tissue'),
#  ('adipose tissue', nan),
#  ('aorta', nan),
#  ('bladder organ', nan),
#  ('blastocyst', 'inner cell mass'),
#  ('blood vessel', 'ascending aorta'),
#  ('blood vessel', nan),
#  ('blood || bone marrow || spleen', nan),
#  ('blood || cell culture || skin', nan),
#  ('blood || decidua || placenta', nan),
#  ('blood || hematopoietic system || lung || mediastinal lymph node', nan),
#  ('blood || kidney', nan),
#  ('blood || liver || spleen', nan),
#  ('blood || liver', nan),
#  ('blood || mouth', nan),
#  ('blood', 'blood'),
#  ('blood', 'peripheral blood mononuclear cell'),
#  ('blood', 'umbilical cord blood'),
#  ('blood', 'venous blood'),
#  ('blood', nan),
#  ('bone marrow', nan),
#  ('bone tissue', nan),
#  ('brain organoids', nan),
#  ('brain || embryo', nan),
#  ('brain || liver || skin', nan),
#  ('brain',
#   'cerebral cortex || hippocampal formation || neural tube ventricular layer'),
#  ('brain', 'cerebral cortex || prefrontal cortex || premotor cortex'),
#  ('brain', 'cerebral cortex'),
#  ('brain', 'cortex of cerebral lobe'),
#  ('brain', 'cortex || substantia nigra'),
#  ('brain', 'cortex'),
#  ('brain', 'hippocampal formation'),
#  ('brain', 'locus ceruleus || substantia nigra'),
#  ('brain', 'locus ceruleus'),
#  ('brain', 'middle temporal gyrus'),
#  ('brain', 'neocortex'),
#  ('brain', 'prefrontal cortex'),
#  ('brain', 'premotor cortex'),
#  ('brain', 'substantia nigra'),
#  ('brain', 'superior parietal cortex'),
#  ('brain', 'temporal cortex'),
#  ('brain', nan),
#  ('cell culture', nan),
#  ('cerebral cortex', nan),
#  ('cerebrospinal fluid', nan),
#  ('colon', 'lamina propria of mucosa of colon'),
#  ('colon', nan),
#  ('cord blood', nan),
#  ('decidua', nan),
#  ('diaphragm', nan),
#  ('digestive system', 'colon'),
#  ('digestive system', nan),
#  ('embryo || endoderm || presumptive gut', nan),
#  ('embryo || kidney', nan),
#  ('embryo', 'blastocyst'),
#  ('embryo', 'skin epidermis'),
#  ('embryo', nan),
#  ('endoderm', 'definitive endoderm || visceral endoderm'),
#  ('endoderm', 'parietal endoderm'),
#  ('endoderm', 'yolk sac endoderm'),
#  ('endoderm', nan),
#  ('esophagus', 'esophagus mucosa'),
#  ('esophagus', nan),
#  ('eye', 'cornea'),
#  ('eye', 'fovea centralis'),
#  ('eye', 'retina'),
#  ('eye', 'retinal neural layer'),
#  ('eye', nan),
#  ('fetal gonads', nan),
#  ('gonad', 'germ layer'),
#  ('heart',
#   'apex of heart || heart left ventricle || heart right ventricle || interventricular septum || left cardiac atrium || right cardiac atrium'),
#  ('heart', 'apex of heart'),
#  ('heart',
#   'atrioventricular bundle || atrioventricular node || heart left ventricle || heart right ventricle || left branch of atrioventricular bundle || right branch of atrioventricular bundle || sinoatrial node'),
#  ('heart', 'atrioventricular bundle || atrioventricular node'),
#  ('heart', 'heart left ventricle || left branch of atrioventricular bundle'),
#  ('heart', 'heart left ventricle'),
#  ('heart', 'heart right ventricle || right branch of atrioventricular bundle'),
#  ('heart', 'heart right ventricle'),
#  ('heart', 'interventricular septum'),
#  ('heart', 'left cardiac atrium'),
#  ('heart', 'right cardiac atrium'),
#  ('heart', 'sinoatrial node'),
#  ('heart', nan),
#  ('hematopoietic system', 'blood'),
#  ('hematopoietic system', 'bone marrow'),
#  ('hematopoietic system', 'peritoneal fluid'),
#  ('hematopoietic system', nan),
#  ('immune organ', 'mesenteric lymph node'),
#  ('immune system', 'bone marrow'),
#  ('kidney || liver || yolk sac || zone of skin', nan),
#  ('kidney || zone of skin', nan),
#  ('kidney', 'cortex of kidney || renal medulla || renal pelvis || ureter'),
#  ('kidney', 'cortex of kidney'),
#  ('kidney', 'cortex'),
#  ('kidney', 'renal medulla'),
#  ('kidney', 'renal pelvis'),
#  ('kidney', 'ureter'),
#  ('kidney', nan),
#  ('large intestine || lymph node', nan),
#  ('large intestine', 'caecum || sigmoid colon || transverse colon'),
#  ('large intestine', 'caecum'),
#  ('large intestine', 'sigmoid colon'),
#  ('large intestine', 'transverse colon'),
#  ('large intestine', nan),
#  ('liver', 'caudate lobe'),
#  ('liver', 'cortex'),
#  ('liver', 'liver parenchyma'),
#  ('liver', nan),
#  ('lung', 'Left lateral basal bronchopulmonary segment'),
#  ('lung',
#   'lower lobe of left lung || lower lobe of right lung || lung parenchyma'),
#  ('lung', 'lower lobe of left lung || lung parenchyma'),
#  ('lung', 'lower lobe of right lung || lung parenchyma'),
#  ('lung', 'lung epithelium'),
#  ('lung', nan),
#  ('lymph node || skin of body', nan),
#  ('lymph node', 'axillary lymph node'),
#  ('lymph node', 'craniocervical lymph node'),
#  ('lymph node', nan),
#  ('mammary gland', nan),
#  ('mediastinal lymph node', 'mediastinal lymph node'),
#  ('mediastinal lymph node', nan),
#  ('mouth',
#   'buccal mucosa || gingiva of lower jaw || larynx || mandible || mouth floor || oral cavity || posterior part of tongue || supraglottic part of larynx || tongue || tonsil'),
#  ('mouth', 'buccal mucosa'),
#  ('mouth', 'gingiva of lower jaw'),
#  ('mouth', 'larynx'),
#  ('mouth', 'mandible'),
#  ('mouth', 'mouth floor'),
#  ('mouth', 'oral cavity'),
#  ('mouth', 'posterior part of tongue'),
#  ('mouth', 'supraglottic part of larynx'),
#  ('mouth', 'tongue'),
#  ('mouth', 'tonsil'),
#  ('mouth', nan),
#  ('muscle organ', nan),
#  ('musculature of limb', nan),
#  ('pancreas', 'ilset of langerhans'),
#  ('pancreas', 'islet of Langerhans'),
#  ('pancreas', nan),
#  ('placenta', 'chorionic villus'),
#  ('placenta', 'decidua'),
#  ('placenta', nan),
#  ('presumptive gut', nan),
#  ('retina', 'fovea centralis || peripheral region of retina'),
#  ('retina', 'fovea centralis'),
#  ('retina', 'peripheral region of retina'),
#  ('skeletal muscle organ', 'diaphragm || quadriceps femoris'),
#  ('skeletal muscle organ', 'diaphragm'),
#  ('skeletal muscle organ', 'quadriceps femoris'),
#  ('skeletal muscle organ', 'vastus lateralis'),
#  ('skeletal muscle', nan),
#  ('skin of body', 'skin epidermis'),
#  ('skin of body', nan),
#  ('skin', 'skin of body'),
#  ('skin', nan),
#  ('small intestine', 'ileum'),
#  ('spleen', nan),
#  ('striatum', nan),
#  ('tail', 'fibroblast'),
#  ('tail', 'tail'),
#  ('testis', 'epididymis'),
#  ('testis', nan),
#  ('thymus', nan),
#  ('tongue', nan),
#  ('tonsil', nan),
#  ('trachea', 'epithelium of trachea'),
#  ('trachea', nan),
#  ('tumor', nan),
#  ('umbilical cord', 'umbilical cord blood'),
#  ('wall of lateral ventricle', nan),
#  ('yolk sac', nan),
#  ('zone of skin', nan)}

# %%
from collections import defaultdict
import numpy as np

os.chdir("C:\\Users\\Robert Yang F\\Desktop\\granatumx")
df = pd.read_csv("TCGA-HCA.csv", sep = ',')

pairs = df.values.tolist()
primary_site_to_HCA_organ = defaultdict(list)
for i in pairs:
    if type(i[1]) == type(''):
        tmp = i[1].split(',')
        primary_site_to_HCA_organ[i[0]] += tmp
    else:
        primary_site_to_HCA_organ[i[0]] = []
        
def clean_str(s):
    return s.strip().replace('(', '').replace(')', '').replace("'", '')

def TCGA_to_HCA(prim_site): # The imput is TCGA primary set, the output is the matching HCA project title and organ
    HCA_organ = []
    HCA_organ_part = []
    project_list = []
    for i in range(len(primary_site_to_HCA_organ[prim_site])):
        if i % 2 == 0:
            HCA_organ.append(clean_str(primary_site_to_HCA_organ[prim_site][i]))
        if i % 2 == 1:
            tmp =  clean_str(primary_site_to_HCA_organ[prim_site][i])
            if tmp == "nan":
                HCA_organ_part.append(float('NaN'))
            else:
                HCA_organ_part.append(tmp)
    for i in range(len(HCA_organ)):
        organ = HCA_organ[i]
        organ_part = HCA_organ_part[i]
        if type(organ_part) != type('str'):
            tmp = project_organ[(project_organ['specimen_from_organism.organ'] == organ) & 
                          (project_organ['specimen_from_organism.organ_part'].isnull())]
        else:
            tmp = project_organ[(project_organ['specimen_from_organism.organ'] == organ) &
                                (project_organ['specimen_from_organism.organ_part'] == organ_part)]
        project_list += list(set([tuple(xi) for xi in tmp[['project.project_core.project_title', 'specimen_from_organism.organ']].values]))
    return set(project_list)

# %%
TCGA_to_HCA('Brain')
# Out:
# {('1.3 Million Brain Cells from E18 Mice', 'brain'),
#  ('A human single cell atlas of the substantia nigra reveals novel cell specific pathways associated with the genetic risk of Parkinson’s disease and neuropsychiatric disorders.',
#   'brain'),
#  ('A survey of human brain transcriptome diversity at the single cell level',
#   'brain'),
#  ('Altered human oligodendrocyte heterogeneity in multiple sclerosis',
#   'brain'),
#  ('Characterization of the transcriptional landscape of human developing hippocampus',
#   'brain'),
#  ('Dissecting the clonal nature of allelic expression in somatic cells by single-cell RNA-seq',
#   'brain'),
#  ('Dissecting the clonal nature of allelic expression in somatic cells by single-cell RNA-seq',
#   'brain || liver || skin'),
#  ('High throughput error corrected Nanopore single cell transcriptome sequencing.',
#   'brain'),
#  ('Human cerebral organoids recapitulate gene expression programs of fetal neocortex development.',
#   'brain'),
#  ('Human cerebral organoids recapitulate gene expression programs of fetal neocortex development.',
#   'brain organoids'),
#  ('Integrative computational analysis of the substantia nigra pars compacta and the locus coeruleus',
#   'brain'),
#  ('Microglia Require CD4\xa0T Cells to Complete the Fetal-to-Adult Transition.',
#   'brain'),
#  ('Single-Cell RNAseq analysis of diffuse neoplastic infiltrating cells at the migrating front of human glioblastoma',
#   'brain'),
#  ('Single-Cell Transcriptomics Reveals a Population of Dormant Neural Stem Cells that Become Activated upon Brain Injury.',
#   'brain'),
#  ('Single-Cell Transcriptomics Reveals a Population of Dormant Neural Stem Cells that Become Activated upon Brain Injury.',
#   'striatum'),
#  ('Single-Cell Transcriptomics Reveals a Population of Dormant Neural Stem Cells that Become Activated upon Brain Injury.',
#   'wall of lateral ventricle'),
#  ('Single-cell RNA Sequencing of human microglia from post mortem Alzheimers Disease CNS tissue.',
#   'brain'),
#  ('Single-cell RNA-seq in monozygotic twins discordant for multiple sclerosis',
#   'cerebrospinal fluid'),
#  ('Single-nucleus RNA sequencing of human cortex affected by multiple sclerosis.',
#   'brain'),
#  ('Systematic comparative analysis of single cell RNA-sequencing methods',
#   'brain'),
#  ('Systematic comparative analysis of single cell RNA-sequencing methods',
#   'brain || embryo'),
#  ('Tabula Muris: Transcriptomic characterization of 20 organs and tissues from Mus musculus at single cell resolution',
#   'adipose tissue || aorta || bladder organ || bone tissue || brain || diaphragm || heart || kidney || large intestine || liver || lung || mammary gland || muscle organ || pancreas || skin of body || spleen || thymus || tongue || trachea'),
#  ('Tabula Muris: Transcriptomic characterization of 20 organs and tissues from Mus musculus at single cell resolution',
#   'brain'),
#  ('Transcriptomic and clonal characterization of T cells in the human central nervous system.',
#   'brain')}

# %%
df2 = pd.read_csv("HCA_project_id_name.csv")
df2.set_index('Project_name').T.to_dict('records') 
# transfer dataframe to dictionary, the key is the title name and the value is the project ID
# Out:
# [{'1.3 Million Brain Cells from E18 Mice': '74b6d569-3b11-42ef-b6b1-a0454522b4a0',
#   'A Cellular Atlas of Pitx2-Dependent Cardiac Development.': '7027adc6-c9c9-46f3-84ee-9badc3a4f53b',
#   'A Single-Cell Transcriptomic Map of the Human and Mouse Pancreas Reveals Inter- and Intra-cell Population Structure': 'f86f1ab4-1fbb-4510-ae35-3ffd752d4dfc',
#   'A cell atlas of human thymic development defines T cell repertoire formation': 'c1810dbc-16d2-45c3-b45e-3e675f88d87b',
#   "A human single cell atlas of the substantia nigra reveals novel cell specific pathways associated with the genetic risk of Parkinson's disease and neuropsychiatric disorders.": '996120f9-e84f-409f-a01e-732ab58ca8b9',
#   'A revised airway epithelial hierarchy includes CFTR-expressing ionocytes': '6072616c-8794-4b20-8f52-fb15992ea5a4',
#   'A single cell atlas of the human proximal epididymis reveals cell-type specific functions and distinct roles for CFTR.': '842605c7-375a-47c5-9e2c-a71c2c00fcad',
#   'A single-cell molecular map of mouse gastrulation and early organogenesis': '1defdada-a365-44ad-9b29-443b06bd11d6',
#   'A single-cell reference map of transcriptional states for human blood and tissue T cell activation': '4a95101c-9ffc-4f30-a809-f04518a23803',
#   'A single-cell survey of the human first-trimester placenta and decidua': '1cd1f41f-f81a-486b-a05b-66ec60f81dcf',
#   'A single-cell transcriptome atlas of the adult human retina': '8185730f-4113-40d3-9cc3-929271784c2b',
#   'A survey of human brain transcriptome diversity at the single cell level': '52b29aa4-c8d6-42b4-807a-b35be94469ca',
#   'Altered human oligodendrocyte heterogeneity in multiple sclerosis': '38449aea-70b5-40db-84b3-1e08f32efe34',
#   'An Atlas of Immune Cell Exhaustion in HIV-Infected Individuals Revealed by Single-Cell Transcriptomics.': '0fd8f918-62d6-4b8b-ac35-4c53dd601f71',
#   'Assessing the relevance of organoids to model inter-individual variation': '005d611a-14d5-4fbf-846e-571a1f874f70',
#   'Bone marrow plasma cells from hip replacement surgeries': 'a29952d9-925e-40f4-8a1c-274f118f1f51',
#   'Cell hashing with barcoded antibodies enables multiplexing and doublet detection for single cell genomics': 'f81efc03-9f56-4354-aabb-6ce819c3d414',
#   'Cells of the adult human heart': 'ad98d3cd-26fb-4ee3-99c9-8a2ab085e737',
#   'Census of Immune Cells': 'cc95ff89-2e68-4a08-a234-480eca21ce79',
#   'Characterization of the transcriptional landscape of human developing hippocampus': '6c040a93-8cf8-4fd5-98de-2297eb07e9f6',
#   'Colonic single epithelial cell census reveals goblet cell drivers of barrier breakdown in inflammatory bowel disease.': 'c893cb57-5c9f-4f26-9312-21b85be84313',
#   'Comparative analysis of kidney organoid and adult human kidney single cell and single nucleus transcriptomes': '16ed4ad8-7319-46b2-8859-6fe1c1d73a82',
#   'Comparison, calibration, and benchmarking of high-throughput single cell RNA-Seq techniques for unbiased cell-type classification': 'a9c022b4-c771-4468-b769-cabcf9738de3',
#   'Decoding the development of the blood and immune systems during human fetal liver haematopoiesis': 'f2fe82f0-4454-4d84-b416-a885f3121e59',
#   'Defining the Activated Fibroblast Population in Lung Fibrosis Using Single Cell Sequencing.': 'b4a7d12f-6c2f-40a3-9e35-9756997857e3',
#   'Direct exposure to SARS-CoV-2 and cigarette smoke increases infection severity and alters the stem cell-derived airway repair response': '2a64db43-1b55-4639-aabb-8dba0145689d',
#   'Dissecting the clonal nature of allelic expression in somatic cells by single-cell RNA-seq': 'ccef38d7-aa92-4010-9621-c4c7b1182647',
#   'Dissecting the human liver cellular landscape by single cell RNA-seq reveals novel intrahepatic monocyte/ macrophage populations': '4d6f6c96-2a83-43d8-8fe1-0f53bffd4674',
#   'Dissecting the protein and transcriptional responses of human immune cells to T cell and monocyte specific activation': 'efea6426-510a-4b60-9a19-277e52bfa815',
#   'Distinct microbial and immune niches of the human colon': '83f5188e-3bf7-4956-9544-cea4f8997756',
#   'GM-CSF-producing T helper cells: a distinct subset of T helper cells.': '41fb1734-a121-4616-95c7-3b732c9433c7',
#   'High throughput error corrected Nanopore single cell transcriptome sequencing.': '0d4b87ea-6e9e-4569-82e4-1343e0e3259f',
#   'Human cerebral organoids recapitulate gene expression programs of fetal neocortex development.': 'd2111fac-3fc4-4f42-9b6d-32cd6a828267',
#   'Identification of a mesenchymal progenitor cell hierarchy in adipose tissue (scRNA-seq)': '42d4f8d4-5422-4b78-adae-e7c3c2ef511c',
#   'Immune landscape of viral- and carcinogen-drived head and neck cancer': '3089d311-f9ed-44dd-bb10-397059bad4dc',
#   'Immunophenotyping of COVID-19 and influenza highlights the role of type I interferons in development of severe COVID-19': '95f07e6e-6a73-4e1b-a880-c83996b3aa5c',
#   'Integrative computational analysis of the substantia nigra pars compacta and the locus coeruleus': '5b5f05b7-2482-468d-b76d-8f68c04a7a47',
#   'Ischaemic sensitivity of human tissue by single cell RNA seq': 'c4077b3c-5c98-4d26-a614-246d12c2e5d7',
#   'Massively parallel single-cell RNA-seq analysis of 26,677 pancreatic islets cells from both healthy and type II diabetic (T2D) donors.': '1c6a960d-52ac-44ea-b728-a59c7ab9dc8e',
#   'Melanoma infiltration of stromal and immune cells': '8c3c290d-dfff-4553-8868-54ce45f4ba7f',
#   'Microglia Require CD4 T Cells to Complete the Fetal-to-Adult Transition.': 'e5d45579-1f5b-48c3-b568-320d93e7ca72',
#   'Molecular transitions in early progenitors during human cord blood hematopoiesis': '63b5b6c1-bbcd-487d-8c2e-0095150c1ecd',
#   'Multiplexing droplet-based single cell RNA-sequencing using genetic barcodes': 'a96b71c0-78a7-42d1-88ce-83c78925cfeb',
#   'Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis': '90bd6933-40c0-48d4-8d76-778c103bf545',
#   'Profiling of CD34+ cells from human bone marrow to understand hematopoiesis': '091cf39b-01bc-42e5-9437-f419a66c8a45',
#   'RNA Sequencing of Single Human Islet Cells Reveals Type 2 Diabetes Genes': '7adede6a-0ab7-45e6-9b67-ffe7466bec1f',
#   'Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics': 'f83165c5-e2ea-4d15-a5cf-33f3550bffde',
#   'Resolving the fibrotic niche of human liver cirrhosis using single-cell transcriptomics': 'c41dffbf-ad83-447c-a0e1-13e689d9b258',
#   'Single Cell RNA-Seq Analysis Reveals  Fate Decision of Human Pre-cDC Determined  by Transcription Factor Competition': 'ce33dde2-382d-448c-b6ac-bfb424644f23',
#   'Single Cell Transcriptomics of a Human Kidney Allograft Biopsy Defines a Diverse Inflammatory Response': '027c51c6-0719-469f-a7f5-640fe57cbece',
#   'Single cell RNA sequencing of multiple myeloma II': '0c3b7785-f74d-4091-8616-a68757e4c2a8',
#   'Single cell RNA-sequencing of human tonsil Innate lymphoid cells (ILCs)': '520afa10-f9d2-4e93-ab7a-26c4c863ce18',
#   'Single cell analysis of human fetal liver captures the transcriptional profile of hepatobiliary hybrid progenitors': '23587fb3-1a4a-4f58-ad74-cc9a4cb4c254',
#   'Single cell profiling of human induced dendritic cells generated by direct reprogramming of embryonic fibroblasts': '116965f3-f094-4769-9d28-ae675c1b569c',
#   'Single cell transcriptome analysis of human pancreas reveals transcriptional signatures of aging and somatic mutation patterns.': 'cddab57b-6868-4be4-806f-395ed9dd635a',
#   'Single cell transcriptomics defines human islet cell signatures and reveals cell-type-specific expression changes in type 2 diabetes [single cell]': 'c6ad8f9b-d26a-4811-b2ba-93d487978446',
#   'Single-Cell RNA-Seq Analysis Maps Development of Human Germline Cells and Gonadal- Niche Interactions': '08b794a0-519c-4516-b184-c583746254c5',
#   'Single-Cell RNA-Seq Reveals Transcriptional Heterogeneity in Latent and Reactivated HIV-infected Cells': 'eaefa1b6-dae1-4414-953b-17b0427d061e',
#   'Single-Cell RNAseq analysis of diffuse neoplastic infiltrating cells at the migrating front of human glioblastoma': '2d846095-8a33-4f3c-97d4-585bafac13b4',
#   'Single-Cell Transcriptomics Reveals a Population of Dormant Neural Stem Cells that Become Activated upon Brain Injury.': 'e8808cc8-4ca0-4096-80f2-bba73600cba6',
#   'Single-cell RNA Sequencing of human microglia from post mortem Alzheimers Disease CNS tissue.': 'b51f49b4-0d2e-4cbd-bbd5-04cd171fc2fa',
#   'Single-cell RNA sequencing of normal human kidney': '2ef3655a-973d-4d69-9b41-21fa4041eed7',
#   'Single-cell RNA sequencing reveals the heterogeneity of liver-resident immune cells in human.': '559bb888-7829-41f2-ace5-2c05c7eb81e9',
#   'Single-cell RNA-Seq Investigation of Foveal and Peripheral Expression in the Human Retina': '4bec484d-ca7a-47b4-8d48-8830e06ad6db',
#   'Single-cell RNA-seq analysis  throughout a 125-day differentiation protocol that converted H1 human embryonic stem cells to a variety of ventrally-derived cell types.': '2043c65a-1cf8-4828-a656-9e247d4e64f1',
#   'Single-cell RNA-seq analysis of human pancreas from healthy individuals and type 2 diabetes patients': 'ae71be1d-ddd8-4feb-9bed-24c3ddb6e1ad',
#   'Single-cell RNA-seq in monozygotic twins discordant for multiple sclerosis': '0c09fade-e079-4fde-8e60-6725b8c1d84b',
#   'Single-cell RNA-seq of human peripheral blood NKT cells': 'f48e7c39-cc67-4055-9d79-bc437892840c',
#   'Single-cell RNA-seq reveals heterogeneity within human pre-cDCs': '05be4f37-4506-429b-b112-506444507d62',
#   'Single-cell RNA-sequencing of skin, fresh blood, and cultured peripheral blood mononuclear cells from a patient with drug-induced hypersensitivity syndrome and healthy volunteers': '9d97f01f-9313-416e-9b07-560f048b2350',
#   'Single-cell RNA-sequencing reveals profibrotic roles of distinct epithelial and mesenchymal lineages in pulmonary fibrosis': 'c1a9a93d-d9de-4e65-9619-a9cec1052eaa',
#   'Single-cell Transcriptome Analysis Reveals Dynamic Cell Populations and Differential Gene Expression Patterns in Control and Aneurysmal Human Aortic Tissue.': '07073c12-8006-4710-a00b-23abdb814904',
#   "Single-cell analysis of Crohn's disease lesions identifies a pathogenic cellular module associated with resistance to anti-TNF therapy.": '992aad5e-7fab-46d9-a47d-df715e8cfd24',
#   'Single-cell analysis reveals the continuum of human lympho-myeloid progenitor cells': '1ce3b3dc-02f2-44a8-96da-d6d107b27a76',
#   'Single-cell omics reveal human mononuclear phagocyte heterogeneity and inflammatory DC in health and disease': 'ccd1f1ba-74ce-469b-9fc9-f6faea623358',
#   'Single-cell survey of human lymphatics unveils marked endothelial cell heterogeneity and mechanisms of homing for neutrophils': '5ee710d7-e2d5-4fe2-818d-15f5e31dae32',
#   'Single-cell transcriptional profiles in human and mouse skeletal muscle': 'a39728aa-70a0-4201-b0a2-81b7badf3e71',
#   'Single-cell transcriptomics uncovers human corneal limbal stem cells and their differentiation trajectory.': '24c654a5-caa5-440a-8f02-582921f2db4a',
#   'Single-nucleus RNA sequencing of human cortex affected by multiple sclerosis.': 'ce7b12ba-664f-4f79-8fc7-3de6b1892183',
#   'Spatial and single-cell transcriptional profiling identifies functionally distinct human dermal fibroblast subpopulations': '05657a59-9f9d-4bb9-b77b-24be13aa5cea',
#   'Spatio-temporal immune zonation of the human kidney': 'abe1a013-af7a-45ed-8c26-f3793c24a1f4',
#   'Structural Remodeling of the Human Colonic Mesenchyme in Inflammatory Bowel Disease': 'f8aa201c-4ff1-45a4-890e-840d63459ca2',
#   'Systematic comparative analysis of single cell RNA-sequencing methods': '88ec040b-8705-4f77-8f41-f81e57632f7d',
#   'Tabula Muris: Transcriptomic characterization of 20 organs and tissues from Mus musculus at single cell resolution': 'e0009214-c0a0-4a7b-96e2-d6a83e966ce0',
#   'The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy': '577c946d-6de5-4b55-a854-cd3fde40bff2',
#   'The emergent landscape of the mouse gut endoderm at single-cell resolution': '4e6f083b-5b9a-4393-9890-2a83da8188f1',
#   'Tracing pluripotency of human early embryos and embryonic stem cells by single cell RNA-seq': '3a694703-3084-4ece-9abe-d935fd5f6748',
#   'Transcriptomes of 1,529 individual cells from 88 human preimplantation embryos': '03c6fce7-789e-4e78-a27a-664d562bb738',
#   'Transcriptomic Profiling of the Developing Cardiac Conduction System at Single-Cell Resolution.': '2086eb05-10b9-432b-b7f0-169ccc49d270',
#   'Transcriptomic and clonal characterization of T cells in the human central nervous system.': 'd3a4ceac-4d66-4984-9704-2570c0647a56',
#   'Transcriptomic characterisation of haematopoietic stem and progenitor cells from human adult bone marrow, spleen and peripheral blood': '455b46e6-d8ea-4611-861e-de720a562ada',
#   'Transcriptomic classification of human retinal cell types with single-nuclei RNA-seq.': '9c20a245-f2c0-43ae-82c9-2232ec6b594f'}]

# %% [markdown]
# ## Meta data in TCGA

# %%
import os
path = 'E:\\HCA_save'
os.chdir(path)

DNA = pd.read_csv('jhu-usc.edu_UCEC.HumanMethylation27.2.lvl-3.TCGA-A5-A0G2-01A-11D-A039-05.gdc_hg38.txt', sep = '\t')
DNA
# Out:
#       Composite Element REF  Beta_value Chromosome      Start        End  \
# 0                cg00000292    0.944106      chr16   28878779   28878780
# 1                cg00002426    0.128014       chr3   57757816   57757817
# 2                cg00003994    0.285217       chr7   15686237   15686238
# 3                cg00005847    0.631192       chr2  176164345  176164346
# 4                cg00006414         NaN       chr7  149125745  149125746
# ...                     ...         ...        ...        ...        ...
# 27573            cg27657283    0.036363       chr1   42767852   42767853
# 27574            cg27661264    0.446497      chr20   58852683   58852684
# 27575            cg27662379    0.013272       chr3  128650910  128650911
# 27576            cg27662877    0.020575      chr18   74292360   74292361
# 27577            cg27665659    0.015407       chr7  101154314  101154315
#
#                                              Gene_Symbol  \
# 0                     ATP2A1;ATP2A1;ATP2A1;ATP2A1;ATP2A1
# 1                    SLMAP;SLMAP;SLMAP;SLMAP;SLMAP;SLMAP
# 2                                                  MEOX2
# 3             AC009336.19;HOXD3;HOXD3;HOXD3;RP11-387A1.5
# 4                         RN7SL521P;ZNF398;ZNF425;ZNF425
# ...                                                  ...
# 27573  C1orf50;C1orf50;C1orf50;P3H1;P3H1;P3H1;P3H1;P3...
# 27574  GNAS;GNAS;GNAS;GNAS;GNAS;GNAS;GNAS;GNAS;GNAS;G...
# 27575                      RPN1;RPN1;RPN1;RPN1;RPN1;RPN1
# 27576                      CYB5A;CYB5A;CYB5A;CYB5A;CYB5A
# 27577                                  AP1S1;AP1S1;AP1S1
#
#                                                Gene_Type  \
# 0      protein_coding;protein_coding;protein_coding;p...
# 1      protein_coding;protein_coding;protein_coding;p...
# 2                                         protein_coding
# 3      protein_coding;protein_coding;protein_coding;p...
# 4      misc_RNA;protein_coding;protein_coding;protein...
# ...                                                  ...
# 27573  protein_coding;protein_coding;protein_coding;p...
# 27574  protein_coding;protein_coding;protein_coding;p...
# 27575  protein_coding;protein_coding;protein_coding;p...
# 27576  protein_coding;protein_coding;protein_coding;p...
# 27577       protein_coding;protein_coding;protein_coding
#
#                                            Transcript_ID  \
# 0      ENST00000357084.6;ENST00000395503.7;ENST000005...
# 1      ENST00000295951.6;ENST00000295952.6;ENST000003...
# 2                                      ENST00000262041.5
# 3      ENST00000468418.4;ENST00000249440.4;ENST000004...
# 4      ENST00000488398.3;ENST00000426851.5;ENST000003...
# ...                                                  ...
# 27573  ENST00000372525.5;ENST00000464081.1;ENST000006...
# 27574  ENST00000306120.3;ENST00000313949.10;ENST00000...
# 27575  ENST00000296255.6;ENST00000476931.1;ENST000004...
# 27576  ENST00000299438.12;ENST00000340533.7;ENST00000...
# 27577  ENST00000337619.8;ENST00000429457.1;ENST000004...
#
#                                          Position_to_TSS  \
# 0                                 373;290;-1275;-465;-83
# 1                               1585;368;261;257;257;514
# 2                                                    576
# 3                              13259;267;3453;27387;1372
# 4                                       242;-672;602;562
# ...                                                  ...
# 27573     582;559;545;-839;-828;-849;-767;-862;-834;-829
# 27574  -774;12964;12934;12934;-581;-32;-581;12178;123...
# 27575                          -60;-89;-88;620;30166;-93
# 27576                          -1318;-343;-386;-424;-402
# 27577                                      -84;-212;-170
#
#                      CGI_Coordinate Feature_Type
# 0       CGI:chr16:28879633-28880547      N_Shore
# 1        CGI:chr3:57756198-57757263      S_Shore
# 2        CGI:chr7:16399497-16399700            .
# 3      CGI:chr2:176164685-176165509      N_Shore
# 4      CGI:chr7:149126122-149127136      N_Shore
# ...                             ...          ...
# 27573    CGI:chr1:42766543-42767688      S_Shore
# 27574   CGI:chr20:58852636-58852940       Island
# 27575  CGI:chr3:128650086-128650962       Island
# 27576   CGI:chr18:74290906-74292535       Island
# 27577  CGI:chr7:101154251-101155198       Island
#
# [27578 rows x 11 columns]
